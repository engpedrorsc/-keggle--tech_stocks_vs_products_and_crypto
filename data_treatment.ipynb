# %% [markdown]
# Loading modules

# %%
import pandas as pd
import os
import glob

# %% [markdown]
# Importing dataset

# %%
# Current working directory

print(f'Current Directiory: {os.getcwd()}')
# Out:
# Current Directiory: /home/pedro/Documents/GitHub/-keggle--tech_stocks_vs_products_and_crypto

# %%
# Search, read and store in dictionary

datasets_dir = './original_datasets'
extensions = ['.csv']
df_dict = {}

for extension in extensions:
    for file in glob.glob(datasets_dir + f'**/**/*{extension}', recursive=True):
        file_path = file
        file_name = os.path.basename(file).split('.')[0]
        df_dict[file_name] = pd.read_csv(file_path)

# %%
# Imported datasets

original_dfs = list(df_dict.keys())
original_dfs
# Out:
# ['cpu_benchmark',
#  'cpu_cinebench_r23',
#  'cpu_specs_amd',
#  'cpu_specs_intel',
#  'gpu_specs',
#  'btc_price',
#  'gpu_scores',
#  'gpu_benchmarks',
#  'stock_intel',
#  'stock_nvidia',
#  'stock_amd']

# %% [markdown]
# Preparing data

# %%
# cpu_benchmark analysis

df = df_dict['cpu_benchmark']
df
# Out:
#                                 cpuName    price  cpuMark  cpuValue  \
# 0     AMD Ryzen Threadripper PRO 5995WX      NaN   108822       NaN
# 1                         AMD EPYC 7763  7299.99    88338     12.10
# 2                         AMD EPYC 7J13      NaN    86006       NaN
# 3                         AMD EPYC 7713  7060.00    85861     12.16
# 4     AMD Ryzen Threadripper PRO 3995WX  6807.98    83971     12.33
# ...                                 ...      ...      ...       ...
# 3820            Intel Pentium 4 1.60GHz      NaN       84       NaN
# 3821            Intel Pentium 4 1400MHz      NaN       83       NaN
# 3822            Intel Pentium 4 1500MHz      NaN       81       NaN
# 3823                   VIA Eden 1000MHz      NaN       80       NaN
# 3824            Intel Pentium 4 1300MHz      NaN       77       NaN
#
#       threadMark  threadValue    TDP powerPerf  cores  testDate    socket  \
# 0           3330          NaN  280.0    388.65     64      2022     sWRX8
# ...
